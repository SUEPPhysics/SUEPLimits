# %%
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from matplotlib import ticker, colors
from scipy import interpolate
from scipy.ndimage import gaussian_filter1d
import matplotlib
from scipy.interpolate import griddata
import numpy as np
import pandas as pd
import os 
import scipy
import uproot
import glob
import yaml
import json

import mplhep as hep
hep.style.use("CMS")
plt.style.use(hep.style.CMS)
matplotlib.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams['figure.dpi'] = 50
matplotlib.rcParams['figure.facecolor'] = 'white'

np.seterr(divide='ignore', invalid='ignore')

#plt.style.use('physics.mplstyle')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
era = 2018
M = 1000
decaymode = 'generic'

# %%
def get_limits(fn): 
    f = uproot.open(fn)
    limit = f["limit"]['limit'].array(library="np")
    quant = f["limit"]['quantileExpected'].array(library="np")
    if limit.shape[0] == 1:
        return -1
    else:
        return np.stack([quant,limit]) 
    
def get_SUEP_file(Mass=125, mdark=2, t=1, decay="generic", path="./"): 
    if t < 10:
        tem = "{0:.2f}".format(t)
    else:
        tem = "{0:.1f}".format(t)
    tem = str(tem).replace(".","p")
    fname = os.path.join(
        "../higgsCombineGluGluToSUEP_HT400_T{}_mS{:.3f}_mPhi{:.3f}_T{:.3f}_mode{}.AsymptoticLimits.mH125.root".format(tem, Mass, mdark, t, decay)
    )
    print(fname)
    if os.path.isfile(fname):
        return fname
    else:
        pass
     
def log_interp1d(xx, yy, kind='linear'): # Returns a linear interpolation through log(x) and log(y)
    logx = np.log(xx)
    logy = np.log(yy)
    lin_interp = interpolate.interp1d(logx, logy, bounds_error=False, fill_value="extrapolate", kind=kind)
    log_interp = lambda zz: np.power(np.e, lin_interp(np.log(zz)))
    return log_interp 


def log_interp2d(xx, yy, zz, method='nearest'): # Returns a linear interpolation through log(x) and log(y)
    logx = np.log(xx)
    logy = np.log(yy)
    logz = np.log(zz)
    points = np.concatenate(((logx.reshape((len(logx),1)), logy.reshape(len(logy),1))), axis=1)
    lin_interp = griddata(points,logz,(logx[None,:], logy[:,None]),method="nearest")
    log_interp = np.power(np.e, lin_interp)
    return log_interp 

def interpLimit(limit, sigma=3):
    x, y = limit.T
    t  = np.linspace(0, 1, len(x))
    t2 = np.linspace(-0.9, 1.2, 100)

    x2 = np.interp(t2, t, x)
    y2 = np.interp(t2, t, y)
    
    x3 = gaussian_filter1d(x2, sigma)
    y3 = gaussian_filter1d(y2, sigma)
    x4 = np.interp(t, t2, x3)
    y4 = np.interp(t, t2, y3)

    return x3, y3

def xs_scale(proc):
    xsec = 1.0
    with open("../config/xsections_%s.json"%era) as file:
            MC_xsecs = json.load(file)
    xsec  = MC_xsecs[proc+"_TuneCP5_13TeV-pythia8"]["xsec"] # xsection in pb
    # xsec *= MC_xsecs[proc]["kr"] # filter efficiency
    # xsec *= MC_xsecs[proc]["br"] 
    #xsec *= 1000.0 # To change from pb to fb
    assert xsec > 0, "{} has a null cross section!".format(proc)
    return xsec

# %%
combine_files = glob.glob("../higgs*{}*.root".format(decaymode))

# %%
all_params = []
for file in combine_files:
    file_trim = file.split("HT400_")[1]
    proc = 'GluGluToSUEP_HT400_' + file_trim.split('.Asymptotic')[0]
    xsec = xs_scale(proc)
    t = float(file_trim.split("_")[0].replace("p",".")[1:])
    Mass = float(file_trim.split("_")[1][2:])
    mphi = float(file_trim.split("_")[2][4:])
    all_params.append([t,Mass,mphi,xsec])

# %%
def get_params(M=M,plot=True):
    params = []
    for pair in all_params:
        if pair[1] != M: continue
        params.append([pair[2],pair[0],pair[3]])

    skip_bad =[]

    for pair in params:
        #limit = get_limits(get_SUEP_file(Mass=M, mdark=pair[0] ,t=pair[1] ,decay=decaymode))
        try:
            limit = get_limits(get_SUEP_file(Mass=M, mdark=pair[0] ,t=pair[1] ,decay=decaymode))
            if limit.shape == (2,5):
                if plot: plt.scatter(pair[0],pair[1], color="green")
                skip_bad.append(pair)
            else:
                print(get_SUEP_file(Mass=M, mdark=pair[0] ,t=pair[1] ,decay=decaymode))

                if plot: plt.scatter(pair[0],pair[1], color="blue", alpha=0.5)
        except:
            print(get_SUEP_file(Mass=M, mdark=pair[0] ,t=pair[1] ,decay=decaymode))
            if plot: plt.scatter(pair[0],pair[1], color="red")

    if plot:
        plt.ylim([0, 40])
        plt.xlim([1, 10])
        plt.xlabel(r"$m_{\phi}$ (GeV)", x=1, ha='right')
        plt.ylabel(r"$T$ (GeV)", y=1, ha='right')
        plt.title(r'$m_{{s}}$= {} GeV'.format(M))
        plt.show()

    return skip_bad
    
params = get_params(M)
# Out:
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS1000.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS1000.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS1000.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS1000.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS1000.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS1000.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS1000.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root

# %%
#Plots a 2D limit plot
def plot_SUEP(params=params,unblind=False,tricontour='log'): 
    
    if tricontour not in ['log','lin']: #tricontour decides whether we interpolate through mu ('lin') or log(mu) ('log')
        raise Exception("tricontour should be 'log' or 'lin'")
    
    # Reorganize data

    limit_mH = [] # T
    limit_ma = [] # mphi
    limit_lm = [] # results for mu
    limit_xs = []
    mZ = 91.1876
    return_limit = []

    for pair in params:
        limit = get_limits(get_SUEP_file(Mass=M, mdark=pair[0] ,t=pair[1] ,decay=decaymode))
        limit = limit #* pair[2] # To plot the xsection rather than mu
        if limit.shape == (2, 5):
            limit_lm.append(limit)
            limit_ma.append(pair[0])
            limit_mH.append(pair[1])
            return_limit.append([pair[0], pair[1], limit[1,2]])
            limit_xs.append(pair[2])
        else: 
            continue

    limit_lm = np.array(limit_lm)
    limit_mH = np.array(limit_mH)
    limit_ma = np.array(limit_ma)
    limit_xs = np.array(limit_xs)
    print(limit_lm)
    if tricontour == 'log':
        limit_lm[:,1,:]= np.log(limit_lm[:,1,:]) # Convert mu to logarithm of mu 
    
    data = pd.DataFrame(
        {
            "mH"  : np.array(limit_mH),
            "ma"  : np.array(limit_ma),
            "m2s" : np.array(limit_lm)[:,1,0],
            "m1s" : np.array(limit_lm)[:,1,1],
            "exp" : np.array(limit_lm)[:,1,2],
            "p1s" : np.array(limit_lm)[:,1,3],
            "p2s" : np.array(limit_lm)[:,1,4],
            #"obs" : np.array(limit_lm)[:,1,5],
        }
    )
    
   

    # Plot figure and obtain mu=1 (log(mu)=0) lines
        
    plt.figure(figsize=(10,10))
    ax = plt.gca()
    
    if tricontour == 'log':
        levels = np.linspace(min(data['exp']),max(data['exp']))
        x = plt.tricontourf(limit_ma, limit_mH, data['exp'], levels =levels, cmap="Wistia")
        plt.colorbar().set_label(r'$log(\mu)$',labelpad=15)
        
    if tricontour == 'lin':
        levels = np.logspace(np.log10(min(data['exp'])),np.log10(max(data['exp'])))
        x = plt.tricontourf(limit_ma, limit_mH, data['exp'], levels =levels,locator=ticker.LogLocator(), cmap="Wistia")
        formatter = ticker.LogFormatter(base=10.0, labelOnlyBase=True) 
        cb = plt.colorbar(format=formatter, label=r'$\mu$')
        cb.ax.set_ylabel(r'$\mu$', rotation=0, va='bottom', fontsize=20)
        cb.locator = ticker.LogLocator(base=10.0, subs=[1.0], numdecs=7, numticks=45)
        cb.update_ticks()

        
     
    
    # Obtain values for expected mu=1 line
    
    # p0 = plt.tricontour(limit_ma, limit_mH, limit_lm[:,1,0],levels=[0,1], colors="k", alpha=0) # -2 sigma expected
    p1 = plt.tricontour(limit_ma, limit_mH, limit_lm[:,1,1],levels=[0,1],   colors="k", alpha=0) # -1 sigma expected
    p2 = plt.tricontour(limit_ma, limit_mH, limit_lm[:,1,2],levels=[0,1],   colors="k", alpha=0) # median expected
    p3 = plt.tricontour(limit_ma, limit_mH, limit_lm[:,1,3],levels=[0,1],  colors="k", alpha=0) # +1 sigma expected
    # p4 = plt.tricontour(limit_ma, limit_mH, limit_lm[:,1,4],levels=[0,1],  colors="k", alpha=0) # +2 sigma expected
    # p5 = plt.tricontour(limit_ma, limit_mH, limit_lm[:,1,5],levels=[0,1],  colors="k", alpha=0) # observed
    
    if tricontour == 'log': x=0
    if tricontour == 'lin': x=1 
    line1 = np.array(p1.collections[x].get_paths()[0].vertices)
    line2 = np.array(p2.collections[x].get_paths()[0].vertices)
    line3 = np.array(p3.collections[x].get_paths()[0].vertices)
    #line4 = np.array(p4.collections[x].get_paths()[0].vertices)
    #line0 = np.array(p0.collections[x].get_paths()[0].vertices)
    #line5 = np.array(p5.collections[x].get_paths()[0].vertices)

    #plot smoothed curve
    plt.plot(*line2.T, "b-", label="Expected $95\%$ CL")
        
    plt.xlabel(r"$m_{\phi}$ (GeV)", x=1, ha='right')
    plt.ylabel(r"$T$ (GeV)", y=1, ha='right')
    cms = plt.text(
        0., 1., u"CMS $\it{preliminary}$",
        fontsize=16, fontweight='bold',
        horizontalalignment='left', 
        verticalalignment='bottom', 
        transform=ax.transAxes
    )
    lumi = plt.text(
        1., 1., r"%.1f fb$^{-1}$ (13 TeV)" % 60.0,
        fontsize=14, horizontalalignment='right', 
        verticalalignment='bottom', 
        transform=ax.transAxes
    )
    
    info = plt.text(
        0.05, 0.87, r"$Ms = {}$ GeV""\n""{}".format(str(M),decaymode),
        fontsize=14, horizontalalignment='left', 
        verticalalignment='bottom', 
        transform=ax.transAxes
    )
    
    plt.xlim([1, 10])
    plt.ylim([0, 40])     
    plt.legend(loc="upper right", fontsize=12)
    plt.tight_layout()
    
    if not os.path.exists('plots'):
        os.makedirs('plots')
    #plt.savefig("/uscms/home/mreid/nobackup/sueps/analysis/SUEPs/scouting/plotter/Plots/{}/color_T_mdark_2D_limits_M{}_{}.pdf".format(outdir,M,decay), bbox_inches='tight')
    #plt.savefig("/uscms/home/mreid/nobackup/sueps/analysis/SUEPs/scouting/plotter/Plots/{}/Color_T_mdark_2D_limits_M{}_{}.png".format(outdir,M,decay), bbox_inches='tight')
    plt.show()

    
    return (line1,line2,line3)

_= plot_SUEP()
# Out:
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS1000.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS1000.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS1000.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS1000.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS1000.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS1000.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS1000.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.82759094e-02 1.14775687e-01 1.54785156e-01 2.07228482e-01
#    2.67945617e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.43022156e-02 7.09229708e-02 9.52148438e-02 1.28613517e-01
#    1.65700763e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.66418457e-02 3.47361565e-02 4.73632812e-02 6.35994002e-02
#    8.21349472e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.41525269e-02 1.89163685e-02 2.58789062e-02 3.49564962e-02
#    4.58908640e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.79194641e-02 1.32585853e-01 1.88476562e-01 2.77878374e-01
#    4.05897498e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.28240204e-02 6.89359158e-02 9.32617188e-02 1.26347035e-01
#    1.63816333e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.89485168e-01 1.47139215e+00 2.36718750e+00 3.82028699e+00
#    5.90513659e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.25813293e-02 4.21702266e-02 5.71289062e-02 7.67126754e-02
#    9.98278558e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.72195435e-02 2.23243237e-02 2.97851562e-02 4.07078490e-02
#    5.27843982e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.70941162e-02 4.98793125e-02 6.98242188e-02 1.00996323e-01
#    1.43179551e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.78398895e-01 3.35847497e+00 2.43125000e+01 2.49908752e+01
#    3.10127754e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.65066528e-02 4.78599072e-02 6.44531250e-02 8.68045464e-02
#    1.11968964e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.47840881e-02 3.20782065e-02 4.34570312e-02 5.90469725e-02
#    7.58941248e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.68228149e-02 2.24854946e-02 3.07617188e-02 4.20425311e-02
#    5.69290668e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.71484375e+02 1.02055933e+03 4.00000000e+03 4.11160938e+03
#    4.15878809e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.21783447e+00 6.96923161e+00 3.38750000e+01 3.42800827e+01
#    4.16630630e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.22473145e-02 2.90064812e-02 3.95507812e-02 5.31087779e-02
#    6.91115931e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.39524841e-02 3.19529176e-02 4.44335938e-02 6.24992438e-02
#    8.63266364e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.13088989e-01 2.88528800e-01 4.10156250e-01 6.04709387e-01
#    8.83300245e-01]]]

# %%
lines = []

for M in [125,200,300,400,500,600,700,800,900,1000]:
    #if M < 800: continue
    lines.append(plot_SUEP(get_params(M)))
# Out:
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS125.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS125.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS125.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS125.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS125.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS125.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS125.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS125.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS125.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS125.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS125.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS125.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS125.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS125.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS125.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS125.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS125.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS125.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS125.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS125.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS125.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS125.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS125.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS125.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS125.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS125.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS125.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS125.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS125.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS125.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS125.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS125.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS125.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS125.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS125.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS125.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS125.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS125.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.10432129e+01 6.86330719e+01 2.63500000e+02 4.98772186e+02
#    5.72032166e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.47192383e-03 2.95257568e-03 4.39453125e-03 6.35641161e-03
#    8.54601059e-03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.72747803e-02 8.69417071e-01 1.25000000e+01 1.25498257e+01
#    1.28979235e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.52258301e-03 9.59682465e-03 1.41601562e-02 2.18364019e-02
#    3.41056958e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.44738770e-03 6.94942474e-03 1.02539062e-02 1.45046469e-02
#    2.10187025e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.99096680e-01 3.06088924e-01 4.55078125e-01 6.56427801e-01
#    1.05138230e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.82892761e+01 5.52867470e+01 2.24850000e+03 2.38293921e+03
#    3.48784448e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.35063171e-01 1.85142398e-01 2.74414062e-01 4.22080606e-01
#    6.33099318e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.96688080e-01 8.53123069e-01 4.76562500e+00 4.82261276e+00
#    6.31450272e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.39411621e+01 3.96512680e+01 1.28250000e+02 1.28761215e+02
#    2.82845093e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.20605469e+02 8.13895691e+02 4.00000000e+03 4.01594409e+03
#    7.03941992e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.10644531e-02 1.24857903e-01 1.82128906e-01 2.76505470e-01
#    4.11916584e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.44140625e-01 1.02168274e+00 1.50000000e+00 1.78101599e+00
#    2.63898826e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.89099121e-01 1.14307368e+00 1.25000000e+01 1.28487787e+01
#    1.63380260e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.98046875e+02 8.22935120e+02 4.00000000e+03 4.23916260e+03
#    6.20474902e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.91796875e+02 1.86321643e+03 4.00000000e+03 5.00448291e+03
#    5.87138477e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.94549561e-01 9.60635960e-01 1.25000000e+01 1.28487787e+01
#    1.59448709e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.55639648e+00 3.05843210e+00 5.00000000e+01 8.62729874e+01
#    9.06405106e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.11279297e+00 6.02034950e+00 5.00000000e+01 5.61783676e+01
#    7.39656906e+01]]]
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS200.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS200.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS200.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS200.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS200.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS200.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS200.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS200.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS200.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS200.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS200.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS200.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS200.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS200.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS200.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS200.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS200.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS200.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS200.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS200.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS200.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS200.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS200.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS200.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS200.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS200.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS200.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS200.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS200.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS200.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS200.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS200.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS200.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS200.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS200.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS200.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS200.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS200.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.02124023e-03 3.90243530e-03 5.37109375e-03 6.39874535e-03
#    8.57180078e-03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.02124023e-03 3.90243530e-03 5.37109375e-03 7.08384672e-03
#    9.10703558e-03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.14413452e+00 8.35326672e+00 3.36250000e+01 3.45632133e+01
#    5.02948036e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.02124023e-03 3.90243530e-03 5.37109375e-03 7.08384672e-03
#    9.10703558e-03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.56018066e-03 1.18646622e-02 1.61132812e-02 2.45914068e-02
#    3.56507041e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.48429108e-02 8.06349993e-01 1.52343750e+00 1.80884445e+00
#    2.85670424e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.79028130e-01 1.02497734e+02 5.95250000e+02 5.97622681e+02
#    1.19910938e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.96618652e-03 7.94029236e-03 1.12304688e-02 1.66022852e-02
#    2.34569460e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.83254242e-01 2.65021384e-01 3.92578125e-01 6.03830636e-01
#    9.14932907e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.94549561e-01 1.73883414e+00 2.50000000e+01 3.44668503e+01
#    4.01481285e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.70283203e+01 5.61523933e+01 9.90000000e+01 1.23860947e+02
#    1.45316772e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.40979004e-03 5.86891174e-03 8.30078125e-03 1.17418570e-02
#    1.63823459e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.57131958e-02 4.93756533e-02 7.37304688e-02 1.16932712e-01
#    1.84815064e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.70717239e-01 8.11073601e-01 2.74218750e+00 2.81870079e+00
#    4.18789244e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.67529297e+01 6.62517517e+02 4.00000000e+03 4.01594409e+03
#    6.03689893e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.18359375e+03 2.58079541e+03 4.00000000e+03 5.00448291e+03
#    8.55598438e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.67285156e-01 6.79321289e-01 7.50000000e-01 1.27017856e+00
#    1.95697689e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.89099121e-01 1.14307368e+00 1.25000000e+01 1.28487787e+01
#    1.59448709e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.28570557e+01 2.67211266e+01 6.87500000e+01 1.03553139e+02
#    1.29517395e+02]]]
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS300.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS300.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS300.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS300.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS300.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS300.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS300.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS300.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS300.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS300.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS300.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS300.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS300.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS300.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS300.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS300.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS300.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS300.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS300.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS300.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS300.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS300.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS300.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS300.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS300.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS300.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS300.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS300.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS300.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS300.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS300.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS300.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS300.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS300.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS300.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS300.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS300.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS300.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.12695312e-02 7.00950623e-02 1.02539062e-01 1.57716945e-01
#    2.43188396e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.57778168e-01 2.28790712e+00 1.65625000e+01 1.67605572e+01
#    2.08953743e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.11987305e-03 5.32150269e-03 7.32421875e-03 9.65979043e-03
#    1.24186845e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.57055664e-03 4.61196899e-03 6.34765625e-03 8.37181881e-03
#    1.07628610e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.11987305e-03 5.32150269e-03 7.32421875e-03 1.05940197e-02
#    1.38784181e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.02124023e-03 4.48989868e-03 5.37109375e-03 7.76894763e-03
#    1.01775061e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.17166748e+02 1.38722733e+02 9.05500000e+02 9.09109375e+02
#    9.12711670e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.57055664e-03 4.61196899e-03 6.34765625e-03 9.18148365e-03
#    1.20279621e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.76353455e-02 2.39072442e-02 3.36914062e-02 5.00754453e-02
#    7.33987764e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.13217163e-01 1.57480478e+00 3.26562500e+00 3.35674334e+00
#    5.28258657e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.75871506e+01 1.36361221e+02 2.36025000e+03 2.36965796e+03
#    2.37904761e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.57055664e-03 4.61196899e-03 6.34765625e-03 8.37181881e-03
#    1.07628610e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [6.48498535e-03 8.63075256e-03 1.22070312e-02 1.72674377e-02
#    2.37814933e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.62815094e-01 2.26083815e-01 3.38867188e-01 5.41478038e-01
#    8.58542979e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.50000000e+02 2.08837891e+03 4.00000000e+03 6.02490967e+03
#    1.21154590e+04]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.33875046e+01 1.12736809e+02 1.33512500e+03 1.67040247e+03
#    2.55713745e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.17494965e-02 5.79271838e-02 8.83789062e-02 1.43334910e-01
#    2.31515527e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.62935257e-01 7.33526886e-01 1.30859375e+00 1.80412424e+00
#    3.08710408e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.70034790e+00 3.96150041e+00 4.33750000e+01 6.93091888e+01
#    7.59102478e+01]]]
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS400.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS400.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS400.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS400.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS400.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS400.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS400.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS400.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS400.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS400.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS400.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS400.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS400.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS400.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS400.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS400.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS400.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS400.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS400.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS400.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS400.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS400.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS400.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS400.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS400.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS400.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS400.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS400.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS400.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS400.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS400.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS400.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS400.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS400.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS400.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS400.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS400.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS400.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.66918945e-03 6.03103638e-03 8.30078125e-03 1.12124607e-02
#    1.42813055e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.74507904e-01 1.95556319e+00 6.01562500e+00 6.18347454e+00
#    9.18711472e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.11987305e-03 5.32150269e-03 7.32421875e-03 9.65979043e-03
#    1.32069401e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.40463257e+00 9.38484001e+00 7.72500000e+01 9.60332336e+01
#    1.04441544e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.50842285e-03 6.92176819e-03 9.27734375e-03 1.25315739e-02
#    1.59614589e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.66918945e-03 6.03103638e-03 8.30078125e-03 1.12124607e-02
#    1.42813055e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.76353455e-02 2.39072442e-02 3.36914062e-02 5.00754453e-02
#    7.25804120e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.11987305e-03 5.32150269e-03 7.32421875e-03 1.05940197e-02
#    1.31485518e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.56018066e-03 1.18646622e-02 1.61132812e-02 2.25361045e-02
#    3.03920191e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.27331543e-01 4.52555656e-01 6.75781250e-01 1.06097937e+00
#    1.65115070e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.76641846e+00 1.52615757e+01 2.49500000e+02 3.91716034e+02
#    6.18209656e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.11987305e-03 5.32150269e-03 7.32421875e-03 9.65979043e-03
#    1.32069401e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.92858887e-03 6.83116913e-03 9.27734375e-03 1.25315739e-02
#    1.69414263e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.22170258e-02 4.42330092e-02 6.49414062e-02 1.01440556e-01
#    1.59212679e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.65747070e+02 1.33855005e+03 3.07500000e+03 3.84719604e+03
#    6.57741309e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.19647980e+00 3.58012843e+00 3.07500000e+02 4.96259064e+02
#    6.04245850e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.03225708e-02 1.42619610e-02 2.00195312e-02 2.86377911e-02
#    4.09791619e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.02180481e-01 1.44191921e-01 2.21679688e-01 3.64826888e-01
#    5.94362199e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.33465576e+00 3.81270409e+00 3.82812500e+00 6.23905802e+00
#    1.02481403e+01]]]
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS500.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS500.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS500.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS500.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS500.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS500.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS500.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS500.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS500.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS500.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS500.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS500.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS500.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS500.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS500.000_mPhi4.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS500.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS500.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS500.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS500.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS500.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS500.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS500.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS500.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS500.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS500.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS500.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS500.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS500.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS500.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS500.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS500.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS500.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS500.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS500.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS500.000_mPhi4.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS500.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS500.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS500.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS500.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS500.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.79763794e+00 5.33695698e+00 1.15500000e+02 1.57395309e+02
#    1.73294876e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [6.66809082e-03 8.66413116e-03 1.12304688e-02 1.51698003e-02
#    2.02114731e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.74314880e-01 1.35550332e+00 2.20312500e+00 3.17789936e+00
#    5.14497709e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.44738770e-03 7.55023956e-03 1.02539062e-02 1.31967273e-02
#    1.74117051e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.82775879e-03 1.01709366e-02 1.31835938e-02 1.86488330e-02
#    2.36739628e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.96618652e-03 8.26931000e-03 1.12304688e-02 1.44535583e-02
#    1.90699622e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.33514404e-02 1.78456306e-02 2.44140625e-02 3.41456123e-02
#    4.76146862e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.50842285e-03 6.92176819e-03 9.27734375e-03 1.31232524e-02
#    1.73666943e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.04138184e-03 1.11455917e-02 1.51367188e-02 2.04462521e-02
#    2.72415504e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.22169495e-01 1.64749324e-01 2.33398438e-01 3.43178093e-01
#    4.99249250e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.35128662e+02 7.37205933e+02 2.86225000e+03 3.58102026e+03
#    4.84167578e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.50842285e-03 6.92176819e-03 9.27734375e-03 1.25315739e-02
#    1.69414263e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.44738770e-03 7.55023956e-03 1.02539062e-02 1.38506871e-02
#    1.79123934e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.86882019e-02 2.51799822e-02 3.46679688e-02 4.98686507e-02
#    7.02664927e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [6.84814453e-01 1.70934010e+00 2.75000000e+00 3.79135370e+00
#    6.05899572e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.35058594e+01 9.44236511e+02 4.00000000e+03 5.00448291e+03
#    8.55598438e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.08030762e+02 1.19625374e+02 3.17200000e+03 3.18464380e+03
#    3.27297705e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.52258301e-03 1.04265213e-02 1.41601562e-02 2.00302266e-02
#    2.68668830e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.28714752e-02 5.80492467e-02 8.25195312e-02 1.20674990e-01
#    1.75626248e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.31707001e-01 1.84917378e+00 5.32812500e+00 5.47679186e+00
#    8.78653908e+00]]]
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS600.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS600.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS600.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS600.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS600.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS600.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS600.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS600.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS600.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS600.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS600.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS600.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS600.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS600.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS600.000_mPhi4.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS600.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS600.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS600.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS600.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS600.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS600.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS600.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS600.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS600.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS600.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS600.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS600.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS600.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS600.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS600.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS600.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS600.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS600.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS600.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS600.000_mPhi4.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS600.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS600.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS600.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS600.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS600.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.15737915e-02 1.50048733e-02 2.00195312e-02 2.73610130e-02
#    3.49543579e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.31549072e-03 1.22895241e-02 1.61132812e-02 2.15084534e-02
#    2.79513467e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.71679688e-01 6.32377625e-01 8.75000000e-01 1.29004669e+00
#    1.84153950e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.98742676e-03 1.09090805e-02 1.51367188e-02 2.04462521e-02
#    2.64421031e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.52206421e-02 1.95558071e-02 2.78320312e-02 3.89259979e-02
#    5.32094799e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.40759277e-03 1.02052689e-02 1.41601562e-02 1.91271398e-02
#    2.47361623e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.78198242e-01 3.79409647e+00 2.50000000e+01 2.56975574e+01
#    3.81802177e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.41577148e-03 9.93919373e-03 1.31835938e-02 1.78080257e-02
#    2.30302196e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.31549072e-03 1.22895241e-02 1.61132812e-02 2.25361045e-02
#    2.95650810e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.71832275e-02 1.31418228e-01 1.88476562e-01 2.82386005e-01
#    4.19807822e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.68672943e+00 8.03927994e+00 6.90500000e+02 9.57479187e+02
#    1.09579614e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.24792480e-03 9.41753387e-03 1.22070312e-02 1.64889134e-02
#    2.19689924e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.00378418e-03 9.70745087e-03 1.31835938e-02 1.78080257e-02
#    2.23339256e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.73797607e-02 2.36096382e-02 3.27148438e-02 4.54943143e-02
#    6.36304840e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.75061035e-01 1.23484182e+00 1.89843750e+00 3.12433243e+00
#    4.92451096e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.80273438e+02 3.65638245e+02 4.00000000e+03 5.13203613e+03
#    7.46667383e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.70425415e+00 3.39852238e+00 8.76000000e+02 1.09598169e+03
#    1.29808179e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.04138184e-03 1.11455917e-02 1.51367188e-02 2.04462521e-02
#    2.72415504e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.14712524e-02 4.25577164e-02 6.10351562e-02 8.97432268e-02
#    1.32054567e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.02717590e-01 1.81301570e+00 3.23437500e+00 4.25287104e+00
#    7.02226019e+00]]]
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS700.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS700.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS700.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS700.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS700.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS700.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS700.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS700.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS700.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS700.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS700.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS700.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS700.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS700.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS700.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS700.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS700.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS700.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS700.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS700.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS700.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS700.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS700.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS700.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS700.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS700.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS700.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS700.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS700.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS700.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS700.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS700.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS700.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS700.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS700.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS700.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ...
#    9.75000024e-01]
#   [2.42996216e-02 3.21644545e-02 4.44335938e-02 6.17907867e-02
#    8.38456601e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.08456421e-01 4.20568466e-01 6.07421875e-01 9.14915502e-01
#    1.39192212e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.75453125e+02 7.90335571e+02 1.86400000e+03 1.91600989e+03
#    2.95664307e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.27529907e+01 5.50734406e+01 1.63750000e+02 2.02260162e+02
#    2.33445129e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.40075684e-02 1.84335709e-02 2.49023438e-02 3.40344310e-02
#    4.41312194e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.29017639e-02 4.38913703e-02 6.10351562e-02 8.68237615e-02
#    1.20391905e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.25484467e-01 6.76939487e-01 1.00781250e+00 1.51799488e+00
#    2.40004921e+00]]]
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS900.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS900.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS900.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS900.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS900.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS900.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS900.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS900.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS900.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS900.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS900.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS900.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS900.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS900.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS900.000_mPhi4.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS900.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS900.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS900.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS900.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS900.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS900.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS900.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS900.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS900.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS900.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS900.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS900.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS900.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS900.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS900.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS900.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS900.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS900.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS900.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS900.000_mPhi4.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS900.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS900.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS900.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS900.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS900.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.42504883e-02 5.77473640e-02 7.81250000e-02 1.04906224e-01
#    1.35480314e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.39038086e-01 1.87497139e-01 2.65625000e-01 3.89503747e-01
#    5.64307928e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.59230042e-02 4.64953780e-02 6.29882812e-02 8.48317146e-02
#    1.09424219e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.48591614e-02 7.16503859e-02 9.61914062e-02 1.29549220e-01
#    1.66468665e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.61764526e-02 3.38803530e-02 4.58984375e-02 6.16324060e-02
#    8.02035779e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.81274414e-02 2.38552094e-02 3.22265625e-02 4.40445580e-02
#    5.79539835e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.28781128e-01 2.06869006e+00 3.32812500e+00 4.16388607e+00
#    6.37428951e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.86827087e-02 3.71242166e-02 5.02929688e-02 6.75333813e-02
#    8.72154534e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.97715759e-02 2.58232355e-02 3.46679688e-02 4.76576425e-02
#    6.16470203e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.52749634e-02 7.37375021e-02 1.02539062e-01 1.45046473e-01
#    2.01718763e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.64579773e-01 3.77529931e+00 4.91250000e+01 4.93208160e+01
#    5.22522964e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.53410339e-02 3.27990651e-02 4.44335938e-02 5.96654154e-02
#    7.76438937e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.31132507e-02 3.01877260e-02 4.05273438e-02 5.50662801e-02
#    7.13102594e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.22091675e-02 2.91739702e-02 4.00390625e-02 5.53604141e-02
#    7.42926598e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.97387695e-01 2.68370628e-01 3.82812500e-01 5.67447245e-01
#    8.35464478e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.25830078e+01 7.50393448e+01 3.42000000e+02 5.36941406e+02
#    6.54839233e+02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.02527618e+00 3.04391384e+00 6.58750000e+01 6.61375809e+01
#    6.69237823e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.97715759e-02 2.58232355e-02 3.46679688e-02 4.71048877e-02
#    6.12281337e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.18489075e-02 4.24868464e-02 5.90820312e-02 8.26323852e-02
#    1.14090502e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.18237305e-01 4.30343628e-01 6.17187500e-01 9.19784188e-01
#    1.36463630e+00]]]
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS1000.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS1000.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS1000.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS1000.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS1000.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS1000.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS1000.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p50_mS1000.000_mPhi2.000_T0.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi2.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi2.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi2.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi2.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T0p75_mS1000.000_mPhi3.000_T0.750_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T12p0_mS1000.000_mPhi3.000_T12.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p50_mS1000.000_mPhi3.000_T1.500_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T3p00_mS1000.000_mPhi3.000_T3.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T6p00_mS1000.000_mPhi3.000_T6.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi4.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T1p00_mS1000.000_mPhi4.000_T1.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi4.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi4.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T32p0_mS1000.000_mPhi8.000_T32.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T16p0_mS1000.000_mPhi8.000_T16.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T2p00_mS1000.000_mPhi8.000_T2.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T4p00_mS1000.000_mPhi8.000_T4.000_modegeneric.AsymptoticLimits.mH125.root
# ../higgsCombineGluGluToSUEP_HT400_T8p00_mS1000.000_mPhi8.000_T8.000_modegeneric.AsymptoticLimits.mH125.root
# [[[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [8.82759094e-02 1.14775687e-01 1.54785156e-01 2.07228482e-01
#    2.67945617e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.43022156e-02 7.09229708e-02 9.52148438e-02 1.28613517e-01
#    1.65700763e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.66418457e-02 3.47361565e-02 4.73632812e-02 6.35994002e-02
#    8.21349472e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.41525269e-02 1.89163685e-02 2.58789062e-02 3.49564962e-02
#    4.58908640e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [9.79194641e-02 1.32585853e-01 1.88476562e-01 2.77878374e-01
#    4.05897498e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.28240204e-02 6.89359158e-02 9.32617188e-02 1.26347035e-01
#    1.63816333e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [5.89485168e-01 1.47139215e+00 2.36718750e+00 3.82028699e+00
#    5.90513659e+00]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.25813293e-02 4.21702266e-02 5.71289062e-02 7.67126754e-02
#    9.98278558e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.72195435e-02 2.23243237e-02 2.97851562e-02 4.07078490e-02
#    5.27843982e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.70941162e-02 4.98793125e-02 6.98242188e-02 1.00996323e-01
#    1.43179551e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.78398895e-01 3.35847497e+00 2.43125000e+01 2.49908752e+01
#    3.10127754e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [3.65066528e-02 4.78599072e-02 6.44531250e-02 8.68045464e-02
#    1.11968964e-01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.47840881e-02 3.20782065e-02 4.34570312e-02 5.90469725e-02
#    7.58941248e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [1.68228149e-02 2.24854946e-02 3.07617188e-02 4.20425311e-02
#    5.69290668e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [7.71484375e+02 1.02055933e+03 4.00000000e+03 4.11160938e+03
#    4.15878809e+03]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [4.21783447e+00 6.96923161e+00 3.38750000e+01 3.42800827e+01
#    4.16630630e+01]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.22473145e-02 2.90064812e-02 3.95507812e-02 5.31087779e-02
#    6.91115931e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.39524841e-02 3.19529176e-02 4.44335938e-02 6.24992438e-02
#    8.63266364e-02]]
#
#  [[2.50000004e-02 1.59999996e-01 5.00000000e-01 8.39999974e-01
#    9.75000024e-01]
#   [2.13088989e-01 2.88528800e-01 4.10156250e-01 6.04709387e-01
#    8.83300245e-01]]]

# %%
# To run through all masses
masses = [125,200,300,400,500,600,700,800,900,1000]
masses = masses[::-1]

# Define colours
cmap = plt.cm.jet
colors = cmap(np.linspace(0, 1, 10))[::-1]

fig, ax = plt.subplots(figsize=(16,9))

for i, line in enumerate(lines[::-1]):
    if masses[i] in []: continue
    line1,line2,line3 = line
    x1,y1 = interpLimit(line1, 0.1) #Expected $95\%$ CL
    x2,y2 = interpLimit(line2, 0.1)
    x3,y3 = interpLimit(line3, 0.1)

    ax.plot(x2,y2, label=r"$m_{{S}}$ = {} GeV".format(masses[i]),c=colors[i])
    
    y1_interp = np.interp(x2, x1, y1)
    y3_interp = np.interp(x2, x3, y3)
    ax.fill_between(x2,y1_interp, y3_interp, color=colors[i],alpha=0.2)


# Annotate figure
ax.set_xlabel(r"$m_{\phi}$ (GeV)", x=1, ha='right')
ax.set_ylabel(r"$T$ (GeV)", y=1, ha='right')
hep.cms.label(llabel='Preliminary', data=False, lumi=137, ax=ax) # To add CMS lumi scripts
#ax.text(7.7, 9.2,  r"$A^' \rightarrow e^{+}e^{-},\mu^{+}\mu^{-},\pi^{+}\pi^{-}$ with BR=15,15,70%", horizontalalignment='right', verticalalignment='center',fontsize=20)

# # Plot datapoints
# x,y,_= tuple(np.array(get_params(1000,plot=False)).T)
# ax.scatter(x,y,marker='o') 

ax.set_xlim([1., 8.5])
ax.set_ylim([0, 12])

legend = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),frameon=False , fontsize=25, title= 'Expected 95% CL $\pm 1\sigma$')
legend.get_title().set_fontsize(25)

plt.tight_layout()

plt.savefig("/uscms/home/mreid/nobackup/sueps/analysis/SUEPs/scouting/plotter/Plots/2D_summary_limits_{}.pdf".format(decaymode), bbox_inches='tight')
plt.savefig("/uscms/home/mreid/nobackup/sueps/analysis/SUEPs/scouting/plotter/Plots/2D_summary_limits_{}.png".format(decaymode), bbox_inches='tight')

# %%
# To run through all masses
masses = [125,200,300,400,500,600,700,800,900,1000]
masses = masses[::-1]

# Define colours
cmap = plt.cm.jet
colors = cmap(np.linspace(0, 1, 10))[::-1]

# Plot mu=1 lines 
fig, ax = plt.subplots(figsize=(16,9))

for i, line in enumerate(lines[::-1]):
    if masses[i] in [700,900]: continue
    line1,line2,line3 = line
    x1,y1 = interpLimit(line1, 0.1) #Expected $95\%$ CL
    x2,y2 = interpLimit(line2, 0.1)
    x3,y3 = interpLimit(line3, 0.1)

    ax.plot(x2,y2, label=r"$M_{{S}}$ = {} GeV".format(masses[i]),c=colors[i])
    
    y1_interp = np.interp(x2, x1, y1)
    y3_interp = np.interp(x2, x3, y3)
    ax.fill_between(x2,y1_interp, y3_interp, color=colors[i],alpha=0.2)

# Annotate figure
ax.set_xlabel(r"$m_{\phi}$ (GeV)", x=1, ha='right')
ax.set_ylabel(r"$T$ (GeV)", y=1, ha='right')
hep.cms.label(llabel='Preliminary', data=False, lumi=137, ax=ax)
#ax.text(7.5, 10, r"$A^' \rightarrow e^{+}e^{-},\mu^{+}\mu^{-},\pi^{+}\pi^{-}$ with BR=15,15,70%", horizontalalignment='right', verticalalignment='center',fontsize=20)

# Plot theoretically excluded regions
x=[1.4,8]
ax.plot(x, [4 * xi for xi in x], '--',color='black')
ax.plot(x, [0.25 * xi for xi in x], '--',color='black')
ax.plot([1.4]*50, np.linspace(0.5,10.5,50),color='black',marker=(1,2,45),markersize =20, alpha =0.5)
ax.plot([8]*50, np.linspace(0.5,10.5,50),color='black',marker=(1,2,-135),markersize =30, alpha =0.5)
#ax.text(8.4, 5, 'few hard tracks', horizontalalignment='right', verticalalignment='center',fontsize=16,rotation=-90)
#ax.text(1.25, 5, r"$m_{\phi}<2m_{A^'}$", horizontalalignment='right', verticalalignment='center',fontsize=16,rotation=-90)
#ax.text(2.1, 8.4, r'$T/m_{\phi}=4$', horizontalalignment='right', verticalalignment='center',fontsize=16,rotation =65)
#ax.text(6, 0.75, r'$T/m_{\phi}=0.25$', horizontalalignment='right', verticalalignment='center',fontsize=16,rotation =8)

# # # Plot datapoints
# x,y,_= tuple(np.array(get_params(1000,plot=False)).T)
# ax.scatter(x,y,marker='o') 

ax.set_xlim([0.8, 12])
ax.set_ylim([0.0, 11])

legend = ax.legend(loc='center left', bbox_to_anchor=(0.69, 0.5),frameon=False , fontsize=25, title= 'Expected 95% CL $\pm 1\sigma$')
legend.get_title().set_fontsize(25)

plt.tight_layout()

plt.savefig("/uscms/home/mreid/nobackup/sueps/analysis/SUEPs/scouting/plotter/Plots/2D_summary_limits_{}_decluttered.pdf".format(decaymode), bbox_inches='tight')
plt.savefig("/uscms/home/mreid/nobackup/sueps/analysis/SUEPs/scouting/plotter/Plots/2D_summary_limits_{}_decluttered.png".format(decaymode), bbox_inches='tight')
